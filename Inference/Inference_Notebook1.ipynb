# %%
"""
- Use ./env1.yml
"""
# Out:
# '\n- Use ./env1.yml\n'

# %%
"""
Trick 1: Test time augmentation 
- https://towardsdatascience.com/test-time-augmentation-tta-and-how-to-perform-it-with-keras-4ac19b67fb4d
- Definition: Instead of showing the regular, “clean” images, only once to the trained model, 
 we will show it the augmented images several times. 
 We will then average the predictions of each corresponding image and take that as our final guess.
"""
import keras
from keras.preprocessing.image import ImageDataGenerator
#load data
(x_train, y_train), (x_val, y_val) = cifar10.load_data()
x_train, x_val = x_train.astype('float32')/255.,  x_val.astype('float32')/255.
y_train, y_val = to_categorical(y_train), to_categorical(y_val)
#defne model here
####################
#then, create data generator
train_datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        rotation_range=10.,
        fill_mode='reflect',
        width_shift_range = 0.1, 
        height_shift_range = 0.1)

train_datagen.fit(x_train)

tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_datagen.flow(x_val, batch_size=bs, shuffle=False), steps = len(x_val)/bs)
    predictions.append(preds)

pred = np.mean(predictions, axis=0)

np.mean(np.equal(np.argmax(y_val, axis=-1), np.argmax(pred, axis=-1)))
