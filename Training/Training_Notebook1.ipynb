# %%
"""
- Test with datascience bowl 2018
- Use env1.yml
"""

# %%
"""
Trick 1: Training with different batch size
- Some models have a batch size that will make it fit better than other batch sizes
"""
